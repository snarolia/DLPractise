# %%
from icrawler.builtin import GoogleImageCrawler

# %%
types = ["chimpanzee", "orangutan", "gorilla", "gibbon", "monkey", "silverback", "bonobo"]
#google_crawler = GoogleImageCrawler(storage={'root_dir': 'DLPractise/projects/datasets/'})

for _ in types:
    google_crawler=GoogleImageCrawler(storage={"root_dir":f"/Users/siddharthnarolia/Projects/Github/DLPractise/projects/datasets/{_}"})
    google_crawler.crawl(keyword=_, max_num=50)
# Out:
# 2025-09-04 00:01:05,445 - INFO - icrawler.crawler - start crawling...
# 2025-09-04 00:01:05,446 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2025-09-04 00:01:05,447 - INFO - feeder - thread feeder-001 exit
# 2025-09-04 00:01:05,448 - INFO - icrawler.crawler - starting 1 parser threads...
# 2025-09-04 00:01:05,449 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2025-09-04 00:01:07,746 - INFO - parser - parsing result page https://www.google.com/search?q=chimpanzee&ijn=0&start=0&tbs=&tbm=isch
# 2025-09-04 00:01:10,862 - INFO - downloader - image #1	https://upload.wikimedia.org/wikipedia/commons/4/42/015_Chimpanzee_at_Kibale_forest_National_Park_Photo_by_Giles_Laurent.jpg
# 2025-09-04 00:01:10,941 - INFO - downloader - image #2	https://files.worldwildlife.org/wwfcmsprod/images/HERO_Chimpanzee_Uganda/hero_small/5ww9mfzphi_Medium_WW215321.jpg
# ...
